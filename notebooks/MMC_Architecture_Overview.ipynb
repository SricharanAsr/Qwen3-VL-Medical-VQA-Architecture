# %% [markdown]
# # Qwen3-VL-4B Medical VQA: 15-Stage System Architecture Execution
# ### End-to-End Multimodal Clinical Pipeline for Chest & Lung Radiography
# **Author:** Sricharan Asr | **Year:** 2026
#
# This interactive notebook demonstrates each architectural component of the 15-stage Medical VQA system.

# %%
import math, random
print('[*] Initializing Medical VQA Architecture Demonstration...')
stages = [
    '1. Single-Organ Filtering Engine', '2. RadLex Canonicalizer', '3. Reasoning Stratification',
    '4. Open-Ended Prompt Transformer', '5. NF4 Quantization', '6. Joint Vision-Language LoRA',
    '7. Difficulty Weighted Loss', '8. 5,000-Step Training Loop', '9. Token Log-Likelihood Proxy',
    '10. Temperature Scaling Calibration', '11. Verification Controller', '12. Selective Abstention Gate',
    '13. BioBERT Evaluator', '14. Automated Jupyter Engine', '15. PDF Report Generator'
]
for s in stages: print(f'  [LOADED] {s}')

# %%
# Temperature Scaling Demo
import sys; sys.path.insert(0, '../')
from scripts.temperature_scaling_calibrator import run_calibration_demo
run_calibration_demo()

# %%
# BioBERT Clinical Semantic Similarity Evaluation
from scripts.evaluate_biobert_similarity.py import evaluate_samples
evaluate_samples()
